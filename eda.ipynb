# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv("data/train.csv")
pd.options.display.max_columns = train.shape[1]

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
cols=train.select_dtypes(include=object).columns.to_list()
train[cols] = train[cols].astype("category")
train[["MSSubClass"]] = train[["MSSubClass"]].astype("category")
train_y = train["SalePrice"]
train_x = train.drop(labels="SalePrice", axis=1)
# train.describe(include="category")
train.dtypes
# Out:
# Id                  int64
# MSSubClass       category
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
#                    ...
# MoSold              int64
# YrSold              int64
# SaleType         category
# SaleCondition    category
# SalePrice           int64
# Length: 81, dtype: object

# %%
#plots
#sns.displot(x="OverallCond", y="SalePrice", data=train, kind="hist")
sns.displot(x="OverallCond", data=train, kind="kde")

# %%
train["OverallCond"]
# Out:
# 0       5
# 1       8
# 2       5
# 3       5
# 4       5
#        ..
# 1455    5
# 1456    6
# 1457    9
# 1458    6
# 1459    6
# Name: OverallCond, Length: 1460, dtype: int64
